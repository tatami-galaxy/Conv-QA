# %%
import json
from datasets import load_dataset, load_metric, load_from_disk
import pandas as pd
from transformers import T5ForConditionalGeneration, T5Tokenizer
from transformers import AlbertTokenizer, AlbertModel
from transformers import Adafactor
import torch
from torch import nn
import torch.nn.functional as F
import collections
from typing import List
from sklearn.metrics import f1_score
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from collections import defaultdict

# %%
class DataClass:

  def __init__(self, data_dir):
    self.data_dir = data_dir

  def data_csv(self, f, output):

    answers = []
    rewrites = []
    passages = []

    filepath = self.data_dir+f

    with open(filepath) as fl:
      data = json.load(fl)
      
      for d in data:
        answers.append(d['answer'])
        rewrites.append(d['rewrite'])
        passages.append(d['passage'])

      data = {'answer':answers, 'passage':passages, 'rewrite':rewrites}
      df = pd.DataFrame(data)
      df.to_csv(output, index=False)


data = DataClass('/home/ujan/Documents/conv-qa/data/interim/')

data.data_csv('qrecc_train.json', 'train.csv')
data.data_csv('qrecc_test.json', 'test.csv')

qrecc = load_dataset('csv', data_files={'train': 'train.csv', 'test': 'test.csv'})
# Out:
# Using custom data configuration default-e76bcb9545c2e116
# Downloading and preparing dataset csv/default to /home/ujan/.cache/huggingface/datasets/csv/default-e76bcb9545c2e116/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /home/ujan/.cache/huggingface/datasets/csv/default-e76bcb9545c2e116/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
#@title models and hyperparameters

max_length= 384
batch_size = 16
pretrained_model = 't5-base'

t5_tokenizer = T5Tokenizer.from_pretrained(pretrained_model)

t5_model = T5ForConditionalGeneration.from_pretrained(pretrained_model)

# %%
def tokenize_dataset(batch):

  passages = t5_tokenizer(batch['rewrite'], batch['passage'], padding='max_length', truncation='only_second', max_length=max_length, add_special_tokens=True)
  answers = t5_tokenizer(batch['answer'], padding='max_length', truncation=True, max_length=max_length, add_special_tokens=True)
  rewrites = t5_tokenizer(batch['rewrite'], padding='max_length', truncation=True, max_length=max_length, add_special_tokens=True)

  batch['psg_input_ids'] = passages.input_ids
  batch['ans_input_ids']  = answers.input_ids
  batch['psg_attention_mask'] = passages.attention_mask
  batch['rwrt_input_ids'] = rewrites.input_ids

  return batch


# handle examples with no answers
def no_ans(x):
  if isinstance(x['answer'], str): return x
  x['answer'] = 'no_ans'
  return x


# removing examples with no context
qrecc = qrecc.filter(lambda x: isinstance(x['passage'], str))

# removing examples with passage length > 384
#qrecc = qrecc.filter(lambda x: len(e_tokenizer(x['passage']).input_ids) <= max_length)

# no answers
qrecc = qrecc.map(no_ans)

# tokenizing
dataset = qrecc.map(
    tokenize_dataset, 
    batch_size = batch_size,
    batched=True,
    remove_columns=['passage', 'answer', 'rewrite']
)


dataset.set_format(
    type='torch', columns=['psg_input_ids', 'ans_input_ids', 'rwrt_input_ids', 'psg_attention_mask'],)
# Out:
#   0%|          | 0/25 [00:00<?, ?ba/s]
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/24037 [00:00<?, ?ex/s]
#   0%|          | 0/6478 [00:00<?, ?ex/s]
#   0%|          | 0/1503 [00:00<?, ?ba/s]
#   0%|          | 0/405 [00:00<?, ?ba/s]

# %%
train_loader = torch.utils.data.DataLoader(dataset['train'], batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(dataset['test'], batch_size=batch_size)

# %%
def valid_loss():
  
  val_loss = 0
  idx = 0

  for batch in test_loader:
    # rewrite+passge inputs for encoder
    psg_input = batch['psg_input_ids'].to(device)
    psg_attention = batch['psg_attention_mask'].to(device)

    # answer inputs for rc
    ans_input = batch['ans_input_ids'] 
    ans_input[ans_input == t5_tokenizer.pad_token_id] = -100 # tokens with indices set to -100 are ignored (masked)
    ans_input = ans_input.to(device)

    # rc loss
    loss = t5_model(input_ids=psg_input, attention_mask=psg_attention, labels=ans_input).loss

    val_loss += loss.item()

    del psg_input, psg_attention, ans_input, loss

    idx += 1

  return val_loss/idx

# %%
num_epochs = 6

device = torch.device('cuda')
t5_model.to(device)

#t5_model.load_state_dict(torch.load('/home/ujan/Documents/conv-qa/models/finetuned_weights/rc_gen5.pth'))

t5_model.train()


optim = optimizer = Adafactor(
    t5_model.parameters(),
    lr=1e-5,
    eps=(1e-30, 1e-3),
    clip_threshold=1.0,
    decay_rate=-0.8,
    beta1=None,
    weight_decay=0.0,
    relative_step=False,
    scale_parameter=False,
    warmup_init=False
)

for epoch in range(num_epochs):
  
  epoch_loss = 0

  for batch in train_loader:

    # rewrite+passge inputs for encoder
    psg_input = batch['psg_input_ids'].to(device)
    psg_attention = batch['psg_attention_mask'].to(device)

    # answer inputs for rc
    ans_input = batch['ans_input_ids'] 
    ans_input[ans_input == t5_tokenizer.pad_token_id] = -100
    ans_input = ans_input.to(device)

    # rc loss
    loss = t5_model(input_ids=psg_input, attention_mask=psg_attention, labels=ans_input).loss

    epoch_loss += loss.item()

    loss.backward()
    optim.step()
    optim.zero_grad()
    

  print('Train loss after epoch {} : {}'.format(epoch+1, epoch_loss / len(train_loader)))
  t5_model.eval()
  print('Valid loss after epoch {} : {}'.format(epoch+1, valid_loss()))
  
  print('\n')
  t5_model.train()
  torch.save(t5_model.state_dict(), '/home/ujan/Desktop/rc_gen'+str(epoch+1)+'.pth')
# Out:
# Train loss after epoch 1 : 0.8047845386419785
# Valid loss after epoch 1 : 0.6113779529377267
#
#
# Train loss after epoch 2 : 0.6315083886116882
# Valid loss after epoch 2 : 0.5707246081696616
#
#
# Train loss after epoch 3 : 0.5835389507784497
# Valid loss after epoch 3 : 0.5542257139344274
#
#
# Train loss after epoch 4 : 0.5532140438051439
# Valid loss after epoch 4 : 0.5449160399260344
#
#
# Train loss after epoch 5 : 0.5301274461640728
# Valid loss after epoch 5 : 0.5391939025602223
#
#
# Train loss after epoch 6 : 0.5120165204593363
# Valid loss after epoch 6 : 0.5360729444174119

# %% [markdown]
# Train loss after epoch 5 : 0.5301274461640728
# Valid loss after epoch 5 : 0.5391939025602223
#
#
# Train loss after epoch 6 : 0.5120165204593363
# Valid loss after epoch 6 : 0.5360729444174119
#
# batch size 16

# %%
device = torch.device('cuda')
t5_model.to(device)

t5_model.load_state_dict(torch.load('/home/ujan/Documents/conv-qa/models/finetuned_weights/new_rc_gen6.pth'))
t5_model.eval()
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
def compute_f1_from_tokens(gold_toks: List[str], pred_toks: List[str]) -> float:
  common = collections.Counter(gold_toks) & collections.Counter(pred_toks)
  num_same = sum(common.values())

  if len(gold_toks) == 0 or len(pred_toks) == 0:
    # If either is no-answer, then F1 is 1 if they agree, 0 otherwise
    return int(gold_toks == pred_toks)

  if num_same == 0:
    return 0

  precision = 1.0 * num_same / len(pred_toks)
  recall = 1.0 * num_same / len(gold_toks)
  f1 = (2 * precision * recall) / (precision + recall)
  return f1

idx = 0
f1 = 0
rwrt_f1_dict = {}

for batch in test_loader:

  # rewrite+passge inputs for encoder
  psg_input = batch['psg_input_ids'].to(device)
  psg_attention = batch['psg_attention_mask'].to(device)
  ans_input = batch['ans_input_ids'] 
  rwrt_input = batch['rwrt_input_ids']

  outputs = t5_model.generate(input_ids=psg_input, attention_mask=psg_attention)
  output_text = t5_tokenizer.batch_decode(outputs, skip_special_tokens=True)
  true_text = t5_tokenizer.batch_decode(ans_input, skip_special_tokens=True)
  rewrites = t5_tokenizer.batch_decode(rwrt_input, skip_special_tokens=True)

  for i in range(len(output_text)):
    score = compute_f1_from_tokens(true_text, output_text)
    if score < 0.2: rwrt_f1_dict[rewrites[i]] = 0.2
    elif score < 0.4: rwrt_f1_dict[rewrites[i]] = 0.4
    elif score < 0.6: rwrt_f1_dict[rewrites[i]] = 0.6
    elif score < 0.8: rwrt_f1_dict[rewrites[i]] = 0.8
    elif score >= 0.8: rwrt_f1_dict[rewrites[i]] = 1.0
        
    f1 += score
    idx += 1

print(f1 / idx)
# Out:
# 0.3153751157764742

# %%
res = defaultdict(list)
for key, val in sorted(rwrt_f1_dict.items()):
    res[val].append(key)

# %%
res[0.2]
# Out:
# ['after rebel wilson studied at atyp what did she do',
#  'and was paul ryan reelected',
#  'any other aplpication of corn syrup besides baby foods bakery products and beverages',
#  'any other countries that had takes on that was week that was besides canada netherlands and new zealand',
#  'any other interesting information about jusuf kalla besides becoming vice president under joko widodo in 2014 presidential election',
#  'any other interesting points in jusuf kalla article besides kalla being first person to hold two nonconsecutive terms as vice president of indonesia',
#  'any other recognition or awards won by gary ablett sr besides norm smith medal',
#  'anybody else who uses oneman band technique',
#  'anyhing i should know about thor heyerdahl',
#  'anything else about idiom out of blue bestides meaning and origin',
#  'anything else about onces release besides release date in ireland',
#  'anything else interesting about critics responses to film',
#  'anything else interesting in ronald shannon jackson article',
#  'anything else of note about old faithful',
#  'anything else sam thompson did interesting besides having highest rbi to games played ratio in history',
#  'anything else you can share about article',
#  'anything interesting that sticks out that i should know about verity lambert',
#  'are alcoholics generally depressed',
#  'are angora goats good for meat',
#  'are boer goats good for meat',
#  'are confectioners sugar and brown sugar measured same way as granulated sugar',
#  'are dairy products necessary for good health',
#  'are data scientists in high demand',
#  'are goats profitable',
#  'are grand slams held in australia',
#  'are james fauntleroys two grammys for best rb song record',
#  'are lavender plants safe to eat',
#  'are mcdonald brothers still alive',
#  'are orca whales dangerous',
#  'are orca whales really whales',
#  'are percy jackson films based on books',
#  'are smokey mountain boys with roy acuff successful',
#  'are there any alternatives to nicotine',
#  'are there any benefits of consuming turmeric',
#  'are there any benefits to binge drinking',
#  'are there any critics of story ed happy clown',
#  'are there any famous foods in washington dc',
#  'are there any important stats during his yankee seasons for reginald martinez jackson',
#  'are there any methods to prevent global warming getting worse',
#  'are there any other interesting aspects about article about cyclist sean kelly besides his grand tour win',
#  'are there any other interesting aspects about billie jean king besides her achievements',
#  'are there any other interesting aspects about bloc party',
#  'are there any other interesting aspects about bridget jones film adaptations',
#  'are there any other interesting aspects about christopher reeve article',
#  'are there any other interesting aspects about daniel barenboim article',
#  'are there any other interesting aspects about ed happy clown article',
#  'are there any other interesting aspects about eddie cantor',
#  'are there any other interesting aspects about frank hague article',
#  'are there any other interesting aspects about frank swift article',
#  'are there any other interesting aspects about horslips article after their return to studio in 2004',
#  'are there any other interesting aspects about james traficants early career besides his parents town he worked in and where he went to school',
#  'are there any other interesting aspects about john edward besides writing one last time and who his parents were',
#  'are there any other interesting aspects about john hennigans injuries besides not renewing contract due to injury',
#  'are there any other interesting aspects about john kasichs election besides how well supported he was by electorate and when he was elected to house of representatives',
#  'are there any other interesting aspects about judy chicago',
#  'are there any other interesting aspects about lyceum besides revival of hamlet and merchant of venice',
#  'are there any other interesting aspects about mirza basheeruddin madmood ahmads use of missionaries to try to spread teachings dispatching and training them and new schemes importance besides guidelines and actions it preaches',
#  'are there any other interesting aspects about panda bears solo career',
#  'are there any other interesting aspects about patsy clines experimentation with genre besides peoples opinion of her rockabilly attempts',
#  'are there any other interesting aspects about peter cook',
#  'are there any other interesting aspects about shia labeouf article',
#  'are there any other interesting aspects about slipknots first album with corey taylor besides eponymous title',
#  'are there any other interesting aspects about smashing pumpkins article',
#  'are there any other interesting aspects about tank man article besides undentified chinese man standing in front of and shfiting positions to obstruct path of column of tanks leaving tiananmen square with film smuggled out to worldwide audience',
#  'are there any other interesting aspects about that was week that was article',
#  'are there any other interesting aspects about thea trinidad',
#  'are there any other interesting aspects about this article besides immanuel kants stance on major political ideals',
#  'are there any other interesting aspects about this article on agatha christie besides her legacy and and then there were none novel',
#  'are there any other interesting aspects about this article on film tiny furniture',
#  'are there any other interesting aspects about this iberians second punic war article besides rome sending gnaeus and publius cornelius scipio to conquer iberia from carthage',
#  'are there any other interesting aspects about this new order article',
#  'are there any other interesting aspects about toki wartooth article',
#  'are there any other interesting aspects about ukrainians article',
#  'are there any other interesting aspects about vladimir kozlov article',
#  'are there any other interesting saspects about john morrison',
#  'are there any other quotes people said about movie besides once has wonderfully natural performances from two leads',
#  'are there any recent changes in process of becoming monsignor',
#  'are there any side effects of lavender oil',
#  'are there any well known warriors in second punic war with iberians',
#  'are there judges on dancing on ice',
#  'are there other forms of co2 gas',
#  'are there other requirements for visitors to afghanistan',
#  'are there other singles from album revenge by eurythmics besides missionary man',
#  'are there other topics joe lieberman felt strongly about',
#  'can binge drinking damage mental health',
#  'can bottom of ocean freeze',
#  'can dairy products harm you instead',
#  'can lyme disease be cured',
#  'can lyme disease kill you',
#  'can red bull kill you',
#  'can you expand further on process of becoming monsignor',
#  'can you milk angora goats',
#  'can you provide information on three stooges collection',
#  'can you tell me more about steve bikos role in student activist',
#  'can you tell me more about toki warooths band experience besides being rhythm guitarist of dethklok',
#  'can you tell me more about travel visa requirements for afghanistan',
#  'compare and contrast microevolution and macroevolution',
#  'describe 321 method of cooking pork ribs',
#  'describe cell membranes',
#  'describe chemical reaction',
#  'describe experiences of some people who have done lasik',
#  'describe global warming',
#  'describe netflixs subscriber growth over time',
#  'describe oceanic crust',
#  'describe period that follows neolithic event',
#  'describe some of influential pop bands',
#  'describe some of virtual machines disadvantages',
#  'describe supertankers invention',
#  'describe traditional process for making balsamic vinegar',
#  'describe typical withdrawal symptoms when you quit smoking',
#  'did ahmadi followers of new scheme act as missionaries',
#  'did aimee semple mcpherson have any children',
#  'did album 7 by enrique iglesias gain critical success',
#  'did album beautiful world by robin thicke have any singles',
#  'did album infinity by journey have any hit singles',
#  'did alexander graham bell do more work for deaf after experimenting with harmonic telegraph',
#  'did alexander graham bell make any inventions for deaf',
#  'did alison moyet decide to embrace pop',
#  'did all young dudes win any awards',
#  'did anna vissi do any plays after daimones',
#  'did anna vissi host any other shows besides me agapi anna',
#  'did anna vissi pay company that sued her',
#  'did any singles from wallflowers album rebel sweetheart chart',
#  'did anybody else review film besides rotten tomatoes and meta critic',
#  'did anybody write about music in film once',
#  'did anyone else accuse kevin spacey of sexual misconduct besides anthony rapp',
#  'did anyone else play on early version of real love besides lennon',
#  'did anything else interesting happen with tris speaker trade to cleveland indians',
#  'did anything result from charles vs third war with france',
#  'did anything significant happen during christopher reeves time working for harvard summer repertory theater company',
#  'did aretha franklin collaborate with anyone',
#  'did aretha franklin win any awards',
#  'did arundhati roy have lot of novels',
#  'did band horslips reunite for this exhibition of horslips memorabilia in orchard gallery in derry',
#  'did being bond girl have effect on ursula andresss career',
#  'did big boss man win any titles',
#  'did bill russell perform well with any other players',
#  'did billie jean king win any award or recognition',
#  'did billy graham find funding or did radio show get cancelled',
#  'did billy graham retire after his mumps diagnosis',
#  'did billy graham succeed in becoming chaplain',
#  'did bob fitzsimmons have any other accomplishments while being heavy weight champion',
#  'did bob fitzsimmons have any other knock outs',
#  'did bobby timmons make any albums',
#  'did boyz ii men win grammys',
#  'did brian wilson have other successes besides first topten single surfin usa by his band beach boys',
#  'did celebrities do anything special for oprahs show',
#  'did charles bradlaugh consider himself to be christian',
#  'did charles kennedy continue to stay in politics',
#  'did charles v have allies',
#  'did cheap trick begin in 1969',
#  'did chinua achebe win any awards',
#  'did colin cowdrey ever win awards',
#  'did colin cowdrey play in new zealand',
#  'did columbus delano do anything else besides president of woll growers association of america as well as president of springfield mount vernon pittsburgh railroad',
#  'did corbin bleus speed of light have any hits',
#  'did critics like once',
#  'did daniel barenboim move away from buenos aires',
#  'did danny boy and for good times by musician ray price do well in charts',
#  'did danny devito win any awards or recognition for his acting',
#  'did devil wears prada band win any awards for albums',
#  'did diponegoro try anything else before fighting',
#  'did divynls have reputation',
#  'did divynls stay together whole decade of 90s',
#  'did drew carey help write drew carey show',
#  'did dsouza write book also in addition to codirecting hillarys america',
#  'did eddie collins have any family',
#  'did editors band release other albums during 20092010 besides in this light and on this evening',
#  'did either of previous helloween members roland grapow or uli kusch come back',
#  'did elton john aids foundation earn lot of money',
#  'did enrique iglesias collaborate with anyone to make euphoria',
#  'did enrique iglesias tour in 2010 to 2011 period',
#  'did enrique write euphoria album himself',
#  'did eva longoria get alimony from tony parker as result of divorce',
#  'did ferdinand magellan travel in his early life',
#  'did francis galton do any other work after 1899',
#  'did francis galton work with anyone else on his papers',
#  'did frank swift marry',
#  'did frank turner ever go on tour after releasing tape deck heart',
#  'did frank turner release any other albums',
#  'did gary oldman receive any recognition for his role in contender',
#  'did gavin newsom sign any thing in 2007',
#  'did great depression only affected united states of america',
#  'did gypsy set any other records',
#  'did hank snow play any live shows',
#  'did hank snow win any awards',
#  'did he create buildings that were not churches',
#  'did he go into acting after college',
#  'did he release any songs in spanish during 2010 to 2011',
#  'did helloween go on tour during 2000s',
#  'did helloween have critical success in 2000s',
#  'did helloween release new album in 2000s',
#  'did henry irving do anything else than revive hamlet',
#  'did hoodoo gurus win any awards',
#  'did humphrey lyttelton have any major influences',
#  'did iberians believe in just one god',
#  'did iberians go to temple to practice religion',
#  'did infinity by journey band do well',
#  'did it become popular',
#  'did j r jayewardene go to any other schools besides bishops college colombo and royal college colombo',
#  'did jack worrall play football and cricket',
#  'did jackie coogan act all through early childhood',
#  'did jackie coogan do anything other than films',
#  'did jackie coogan go to college',
#  'did jahlil okafor play for anyone else besides duke university and whitney m young magnet high school',
#  'did jane jacobs graduate from college',
#  'did jascha heifetz ever release album',
#  'did jascha heifetz ever release music',
#  'did jascha heifetz ever retire',
#  'did jean lapierre initiate any other agreements besides pacific gateway strategy',
#  'did jeb bush continue his career at texas commerce bank',
#  'did jerry west have any other statistics besides his coaching stats',
#  'did jerry west win any awards',
#  'did jessica mauboy receive any awards or honors during 2010s',
#  'did joe e brown win any awards',
#  'did joe gibbs coached teams win any championships',
#  'did joe sakic receive any award',
#  'did john hennigan have any notable losses',
#  'did john hennigan win any awards on circuit',
#  'did johnny unitas baltimore colts get to play in any championship games like super bowl during 1964 season',
#  'did josephine butler have siblings',
#  'did journey band release any new albums',
#  'did juan sebastián verón sign with someone else after old trafford',
#  'did juan sebastián verón win games in champions league',
#  'did judas priest have any hit singles',
#  'did judas priest tour at all',
#  'did judy chicago exhibit any of her work',
#  'did judy chicago work with any other female artists',
#  'did judy chicago work with any other women',
#  'did julianne hough dance with anyone else on dancing with stars besides helio',
#  'did julius evola develop anything else besides magical idealism',
#  'did jusuf kalla gain any other office besides vice president',
#  'did ken kavanaugh do well in college',
#  'did ken kavanaugh play football',
#  'did ken kavanaugh win any trophies',
#  'did kenneth anger do any work back in paris',
#  'did kevin durant take russell westbrooks place after westbrooks meniscus injury',
#  'did kit carson enjoy exploring as mountain man',
#  'did lady randolph churchill have affairs',
#  'did larry bird ever receive any awards because of his playing',
#  'did larry bird win any other awards besides being 12time nba allstar and nba most valuable player award',
#  'did larry kudlow do anything noteable',
#  'did larry kudlow have other jobs in government besides being associate director for economics and planning in office of management and budget',
#  'did lee trevino go to any other masters besides 1969 masters',
#  'did lena dunham win any other awards for film tiny furniture other than independent spirit award',
#  'did leontyne price get award for her singing efforts and endeavors',
#  'did lester young become successful',
#  'did lou groza do anything else',
#  'did louis slotin recover from his radiation injury',
#  'did luis walter alvarez go on any digs',
#  'did lyceum produce anything else besides cup othello romeo and juliet hamlet and merchant of venice',
#  'did lydia sellon latrobe and benjamin henry latrobe divorce',
#  'did marriage between lady randolph churchhill and montagu porch last',
#  'did martina hingis come back from her 2007 retirement',
#  'did mary chapin carpenter win any awards',
#  'did matthew paris do lot of drawings',
#  'did members of spandau ballet do solo work',
#  'did michael savage ever go back to tv after msnbc or another job',
#  'did mirza basheeruddin mahmood ahmad use missionaries to try to spread new scheme to foreign countries',
#  'did mohammed zahir shah have any issues with his eyes',
#  'did mohammed zahir shah participate in any peace talks',
#  'did mr dj do well',
#  'did muse band tour for resistance of 2nd law album',
#  'did music for jilted generation have any hit singles',
#  'did musician ray price collaborate with any artist in period 19602000s',
#  'did musician ray price do any tours in period 19602000s',
#  'did musician ray price win any awards in period from 1960 to 2000s',
#  'did musician slash overcome cardiomyopathy illness what eventually happened',
#  'did nancy lieberman play in high school',
#  'did natalie maines win awards',
#  'did ned kelly have any other run ins with police besides drunk incident in 1877',
#  'did neutral milk hotel have different name when they started',
#  'did neutral milk hotel produce any hits',
#  'did oklahoma city team win games during playoffs after russell westbrooks meniscus tear',
#  'did one love chart',
#  'did p g wodehouse do anything other than musicals',
#  'did paolo rossi receive any awards or recognition',
#  'did patsy cline release any of her music for decca records',
#  'did people generally disagree or agree with law of peoples',
#  'did people like ken kavanaughs playing style',
#  'did peter hitchens attend any rallys',
#  'did pierre monteux do any other orchestra',
#  'did pierre monteux have any other performances as conductor',
#  'did pierre monteux win any awards',
#  'did prince philip duke of edinburgh have siblings',
#  'did prodigy go on tour',
#  'did prodigy make any other albums besides music for jilted generation',
#  'did production company of anna vissis show win lawsuit against her',
#  'did ratt ever go by different name',
#  'did rebel wilson star in any movies or tv shows during her early career',
#  'did reginald martinez jackson play well during his time with oakland as',
#  'did replacements break up',
#  'did replacements go on tour',
#  'did replacements release other singles',
#  'did ricky lee and doug go solo',
#  'did roaring twenties end with enactment of prohibition',
#  'did robert maynard hutchins pull any sports out of university of chicagos agenda',
#  'did ronald shannon jackson have any tributes made to him',
#  'did ronald shannon jackson perform with anybody',
#  'did rosalynn carter address any other issues',
#  'did rosalynn carter meet with anyone of note',
#  'did rosalynn carter travel anywhere else',
#  'did roy acuff play any other instruments',
#  'did ruhollah khomeini have any family',
#  'did ruhollah khomeini have wife',
#  'did sad wings of destiny eventually become successful',
#  'did sandman and dian belmont have any children',
#  'did satriani play with any other bands besides squares',
#  'did sharon cuneta win any awards',
#  'did shula have any siblings',
#  'did slayer win any awards for album reign in blood',
#  'did slipknot have 3rd album',
#  'did small faces do anything else of importance during hiatus besides forming faces',
#  'did small faces put any records out during hiatus',
#  'did smashing pumpkins go on tour',
#  'did smoky mountain boys with roy acuff produce any records',
#  'did song red strokes“ by garth brooks win any awards',
#  'did sophie ellisbextor and richard jones have relationship',
#  'did stan musial win any awards with cardinals',
#  'did stan musial win major league baseball allstar game',
#  'did steffi graf ever play with any other tennis superstars',
#  'did steve wariner ever work with any artist through his career',
#  'did steve wariner wok with any other artist',
#  'did tanks stop for unidentified chinese man that stood in front of column of tanks leaving tianamen square',
#  'did that was week that was show in other countries besides netherlands and canada',
#  'did this replacement by berklee college of musictrained drummer steve smith who came from jazz background work well',
#  'did three stooges collection sell lot',
#  'did tom cousineau play well during his time at ohio state',
#  'did tom cousineau stay at ohio state for his entire college career',
#  'did tom cruise do anything special while on show',
#  'did tony parker and eva longoria have things in common',
#  'did travis tritt win any awards',
#  'did trevor noah change staff of daily show',
#  'did tris speaker stay with his team boston red sox',
#  'did tris speakers team boston red sox do well with him',
#  'did twin towers feud with anyone else',
#  'did ukrainian language become widely used',
#  'did uli kusch and roland grapow stay in helloween past their 2000s tour',
#  'did verity lambert win any notable awards',
#  'did vladimir kozlovs angle in ruthless roundtable work for group',
#  'did wallflowers album rebel sweetheart rank high on charts',
#  'did we are scientists have any acclaimed singles during time they released brain thrust mastery',
#  'did wesley clark fight in any wars',
#  'did wesley clark win any awards',
#  'did will forte marry',
#  'did will forte win any award or recognition',
#  'did with love and squalor do well',
#  'did wrestler edge have many matches',
#  'did you find anything else of importance or important aspects',
#  'did youve got another thing comin single chart',
#  'do cell membranes repair themselves',
#  'do kooks have same band members',
#  'do lew wallace do any work for us government',
#  'do lokono people still exist today',
#  'do nurse practitioners or physician assistants make more',
#  'do rock performers overlay sounds when they do oneman band recordings',
#  'do taiwanese recognize deaths during february 28 incident',
#  'do we eat dairy cows',
#  'do you know anything about recent life of blake shelton',
#  'do you know teams kurt warner took to super bowl',
#  'do you need milk for strong bones',
#  'does being vegan help you lose weight',
#  'does catherine mccormack also do theatre work',
#  'does co2 gas help living things',
#  'does dome fuji have inhabitants',
#  'does effect of lasik wear off with age',
#  'does joe lieberman have any other political positions',
#  'does joe lieberman support any more causes',
#  'does john mayer work with any other artists for charity',
#  'does john rawls think being decent or liberal person is better',
#  'does jref contribute to any charitable causes',
#  'does jref do anything else noteworthy besides amazng meeting',
#  'does lack of sunlight cause depression',
#  'does melatonin help with jet lag',
#  'does panda bear do any performances other than performing material from tomboy in miami florida',
#  'does public vote also on dancing on ice',
#  'does sam brownback suggest any alternatives to singlepayer governmentrun healthcare',
#  'does terry gilliam always use this ultrawideangle style of filmmaking',
#  'does tesla car autopilot support full selfdriving',
#  'does tony parker get along with his parents',
#  'does wikipedia talk about blake sheltons relationships',
#  'does your article ever show pierre monteux as conductor',
#  'give me example of chemical reaction',
#  'give me example of end product of chemical weathering',
#  'give me short description of lasik procedure',
#  'has anyone ever disagreed with joe liebermans positions',
#  'has gwen stefani been successful',
#  'has lena dunham done other films since tiny furniture',
#  'has public or media criticized sam brownback before about his healthcare views',
#  'has rebel wilson appeared in other things you didnt mention',
#  'has ricky martin ever dated woman',
#  'has sam brownback worked to pass any laws relating to healthcare',
#  'has susan egan been on broadway',
#  'has william b davis won awards for role of smoking man',
#  'have there been violations of apa ethics code',
#  'how about melatonins effect for anxiety',
#  'how and when was largest securities exchange in world created',
#  'how are anxiety and depression related',
#  'how are chemical compounds formed',
#  'how are chemical elements related to periodic table',
#  'how are paleo diet and keto diet different',
#  'how are performances judged on dancing on ice',
#  'how are red blood cells created',
#  'how are spanish christmas lottery tickets sold',
#  'how are spices different from herbs',
#  'how bad was louis slotins radiation injury',
#  'how can fossils be used to understand darwins theory',
#  'how can government reduce level of frictional unemployment',
#  'how can i increase my melatonin levels naturally',
#  'how can you tell if someone is suffering from depression',
#  'how can you treat sad',
#  'how cold is water underneath ice in antarctica',
#  'how did 1860 republican national convention go for william h seward',
#  'how did album iowa fair',
#  'how did album out of ashes by jessi colter do',
#  'how did alexander graham bell help deaf',
#  'how did alexander graham bell help his father',
#  'how did arabic language spread',
#  'how did band members of american band exile meet',
#  'how did bobby jones start playing golf',
#  'how did britpop change music',
#  'how did canadian show this hour has seven days add satire',
#  'how did colin cowdrey do with his oxford university team',
#  'how did critics rate katrina kaifs performance in baar baar dekho',
#  'how did film krays do',
#  'how did frederick ii achieve continuity as holy roman emperor',
#  'how did greeks and phoenicians influence iberian art',
#  'how did harmonic telegraph work',
#  'how did harold shipman die',
#  'how did hulk hogan do in hulkamania let battle begin',
#  'how did jack worrall score 417 for carlton cricket club',
#  'how did joe garlands career progress',
#  'how did kevin clash get his start',
#  'how did kobe bryant come up short',
#  'how did lady randolph churchill second marriage end',
#  'how did lapulapus legend begin',
#  'how did liv tyler gain mainstream exposure',
#  'how did living for city from album innervisions do',
#  'how did lou groza die',
#  'how did members of los angeles gallery shia labeouf occupied for six days wearing paper bag and silently crying in front of visitors react to this',
#  'how did michael anthonys career start',
#  'how did mwai kibaki do in 2002 elections',
#  'how did netflix originally work',
#  'how did pankaj advani snooker career begin',
#  'how did people feel about frederick ii',
#  'how did people feel towards julius evola and his magical idealism',
#  'how did pretty young things tag team start',
#  'how did public react to hans christopher christiansens bethlehem water works',
#  'how did religion effect ancient hawaiin society',
#  'how did resistance and 2nd law albums by muse do on charts',
#  'how did ronald shannon jackson die',
#  'how did second wave of migrations effect ancient hawaiian society or system',
#  'how did small faces wind up getting back together',
#  'how did song dancing in dark perform in music charts',
#  'how did supergirl come to earth',
#  'how did tim kaine work to promote democracy',
#  'how did tradition of tio de nadal start',
#  'how did ukraine obtain distinctive statehood',
#  'how did wallflowers single beautiful side of somewhere do',
#  'how do implied powers of congress work',
#  'how do orca whales hunt',
#  'how do spanish people celebrate three kings day',
#  'how do virtual machines work',
#  'how do you cook pork ribs on bbq',
#  'how do you get lyme disease',
#  'how do you know when pork ribs are done smoking',
#  'how do you sleep after jet lag',
#  'how do you stop atrial flutter attack',
#  'how does atrial fibrillation affect electrocardiography',
#  'how does binge drinking affect development',
#  'how does blockchain work',
#  'how does captivity affect orca whales',
#  'how does chemical compound differ from element',
#  'how does elton john aids foundation raise money',
#  'how does environmental impact compare between being vegan and being vegetarian',
#  'how does lyme disease make you feel',
#  'how does national popular vote interstate compact work',
#  'how does netflix compare to amazon prime video',
#  'how does oceanic crust differ from continental crust',
#  'how does one become monsignor in catholic church',
#  'how does realtime database differ from traditional databases',
#  'how does spanish christmas lottery drawing work',
#  'how does us electoral college work',
#  'how happens to waters molecules when it freezes',
#  'how has netflix changed way tv is watched',
#  'how has netflix impacted society',
#  'how has us electoral college changed over time',
#  'how have electors that dont vote for pledged candidate changed election outcomes',
#  'how is anemia treated',
#  'how is bitcoin generated',
#  'how is blockchain related to cryptocurrencies',
#  'how is container different than virtual machine',
#  'how is decomposition reaction chemical change',
#  'how is docker related kurbenetes',
#  'how is herbert spencers work related to comte',
#  'how is inflation affected by high gdp growth',
#  'how is intermittent fasting related to keto',
#  'how is lavender used in cooking',
#  'how is mass flow rate defined',
#  'how is nominal gdp related to gross national income',
#  'how is ocean crust formed',
#  'how is overpopulation related to global warming',
#  'how is oxygen transported in blood',
#  'how is periodic table organized',
#  'how is richard nixon associated with soviet union',
#  'how is shia labeouf relevant to performance art',
#  'how is surrealism movement different from dada',
#  'how is tofu made',
#  'how long ago was kontiki expedition',
#  'how long can tesla car batteries last',
#  'how long did album all around my hat stay on charts',
#  'how long did billy graham work for church',
#  'how long did chinua achebe travel during his fellowship',
#  'how long did gypsy run',
#  'how long did joe sakic stay with quebec nordiques',
#  'how long did stan kenton stay with gus arnheim',
#  'how long did walter cronkite stay at cbs news',
#  'how long is typical movie',
#  'how long was first feature film',
#  'how long was he minister of transport',
#  'how long was humphrey lyttelton with best of jazz program',
#  'how long was john sherman cooper in office in kentucky house of representatives',
#  'how long was talking heads hiatus',
#  'how long were sandman and dian belmont together',
#  'how many albums did led zeppelin record',
#  'how many barrels can vlcc ship carry',
#  'how many bases did eddie collins steal in season to set record',
#  'how many celebrities did oprah have on her show',
#  'how many copies did with love and squalor sell',
#  'how many costco warehouses are active',
#  'how many cups of granulated sugar does standard 100packet box contain',
#  'how many games did eddie collins play for athletics when he returned',
#  'how many goats can you have per acre',
#  'how many hurricanes have hit state of new york',
#  'how many jesse stone books were made into movies',
#  'how many keys does imperial concert grand piano have',
#  'how many keys on concert grand piano',
#  'how many marriages did lady randolph churchill have',
#  'how many people died as result of february 28 incident',
#  'how many people signed us constitution',
#  'how many people were at whitney houstons funeral',
#  'how many people were in kanjani eight',
#  'how many perfect 100s did nadia comaneci receive',
#  'how many teams did eddie jr play for',
#  'how many teams did joe gibbs coach',
#  'how many teaspoons of granulated sugar are in cup',
#  'how many times has uk participated in eurovision song contest',
#  'how many types of toilets are there',
#  'how many were in diponegoros army',
#  'how many were in millenium novel series by stieg larsson',
#  'how much do data scientists make on average in year',
#  'how much does empty quarter keg weight',
#  'how much longer does it take to become doctor after being nurse practitioner',
#  'how much space do cattle need',
#  'how much time passed before he became professional player',
#  'how necessary is fiber',
#  'how old is nicky jam',
#  'how old is oldest living tree on earth',
#  'how old was aditi ashok in 2016',
#  'how old was bill robinson when he and shirley temple worked together',
#  'how old was cyclist sean kelly when he started cycling',
#  'how old was frank sinatra when he died',
#  'how old was lee trevino',
#  'how old was stan kenton when he started his career',
#  'how reliable is lyme disease test',
#  'how secure is blockchain',
#  'how serious is irregular heart beat',
#  'how successful was hollywood undeads american tragedy album',
#  'how was australian show mavis bramston show seen',
#  'how was bethlehem water works engineered by hans christopher christiansen',
#  'how was colin cowdreys elegance displayed',
#  'how was in this light and on this evening received',
#  'how was jazz age defined',
#  'how was jerry west as coach',
#  'how was lucy stone involved in american equal rights association',
#  'how was melatonin discovered',
#  'how was movie up received',
#  'how was netflix started',
#  'how was new zealands show week of it receieved',
#  'how was supergirl revived',
#  'how well did first steps album do',
#  'how well did living for city from album innervisions do',
#  'how would us electoral college be abolished',
#  'if you dont eat any meat at all is it bad for you',
#  'in general what are effects of consuming energy drinks',
#  'in what city did nadia comaneci earn first perfect 100',
#  'in what part of body is glenoid',
#  'in what year did retirement take place for lew wallace',
#  'in what year was carl jung born',
#  'is america imagine world without her positive or negative',
#  'is balanced diet same for men as well as women',
#  'is brain thrust mastery by we are scientists album or single',
#  'is carbon most abundant element of all',
#  'is first mcdonalds restaurant still open',
#  'is frictional unemployment bad for economy',
#  'is ima album by bt',
#  'is jref still in existence today',
#  'is melatonin bad for you',
#  'is national popular vote interstate compact legal',
#  'is physician assistants above nurse practitioner',
#  'is presenting best of jazz all that humphrey lyttelton did on radio',
#  'is red bull bad for you',
#  'is robert owens models for socialism book',
#  'is satriani still with chickenfoot',
#  'is smoking mans name ever revealed on xfiles',
#  'is spy museum in washington dc free',
#  'is surrealism movement in art still used today',
#  'is terry gilliams style considered unique',
#  'is there 9th jesse stone movie',
#  'is there any cartilage in glenoid cavity',
#  'is there any interesting fact about cyclist sean kellys early years',
#  'is there any interesting information about diponegoro fighting dutch',
#  'is there anything else about julius evola magical idealism besides ego',
#  'is there anything else interesting on william h seward besides his involvement at 1860 republican national convention',
#  'is there anything interesting that happened during francis galtons middle years',
#  'is there anything worth noting about visuals in film once',
#  'is there example of nathan explosions emotional stability',
#  'is there video made for song walk it talk it“',
#  'james fauntleroy won awards',
#  'monothelites maintained that jesus christ had only one will as opposed to what',
#  'my apologies did sascha gestner and mark cross stay in helloween after 2000s tour',
#  'name place in gujarat which has huge tidal mill farms',
#  'once lasik is done what kind of precautions do i need to take',
#  'other than release of their album rebel sweetheart what else happened to wallflowers in 2005',
#  'regarding dj paul what is person of interest',
#  'regarding dj paul what is scale ton',
#  'so pierre monteux was only conductor once before military',
#  'tell about bigos stew',
#  'tell me about author of stanford experiment',
#  'tell me about avengers first appearance',
#  'tell me about blockchains invention',
#  'tell me about boer goats',
#  'tell me about bronze age collapse',
#  'tell me about career options for statistics',
#  'tell me about cold turkey method',
#  'tell me about dc half smokes history',
#  'tell me about evolution by boyz ii men',
#  'tell me about history of toilets',
#  'tell me about lavender plants',
#  'tell me about negative health effects of drinking',
#  'tell me about orca whales',
#  'tell me about origins of justice league in dc universe',
#  'tell me about phospholipid bilayer',
#  'tell me about series of manifestos in surrealism movement',
#  'tell me about surrealism movements founding',
#  'tell me about turmeric',
#  'tell me about types of irregular heart beat',
#  'tell me about us electoral college creation',
#  'tell me differences between synthesis reaction and decomposition reaction',
#  'tell me more about autopilot in tesla cars',
#  'tell me more about ching shih',
#  'tell me more about fairport convention and matty grooves records',
#  'tell me more about frederick iis italian projects',
#  'tell me more about tesla car company',
#  'was 2003 teenage mutant ninja turtles series animated',
#  'was agatha christies and then there were none successful novel',
#  'was album in wake of poseidon by king crimson success',
#  'was album revenge by eurythmics hit',
#  'was alexander graham bells school and system successful',
#  'was alydar affirmeds biggest rival',
#  'was aretha franklin with any other recording company besides atlantic',
#  'was band humble pie successful',
#  'was bobby timmons band popular',
#  'was charles kennedy running as liberal or democrat during 2005 general election',
#  'was chi album successful',
#  'was christopher reeve good student',
#  'was colin cowdrey ever in australia',
#  'was colin cowdrey oxford universitys leading captain',
#  'was dolly partons i will always love you success',
#  'was drakes album so far gone successful',
#  'was exhibition of horslips memorabilia in orchard gallery in derry well received',
#  'was fat of land album success',
#  'was first album released by meat beat manifesto on nothing records successful',
#  'was four star records patsy clines first record label',
#  'was francis galtons work wellreceived',
#  'was gavin newsom ever attacked',
#  'was he successful in diponegoros fight against dutch',
#  'was henry irvings revival of hamlet and merchant of venice successful',
#  'was hillarys america released in theaters',
#  'was hollywood babylon successful',
#  'was ima debut studio album by american electronic musician bt successful',
#  'was irene scanning machine used lot',
#  'was jack worrall football player',
#  'was jerry w kilgore republican',
#  'was john hennigan ever injured',
#  'was john kasich well supported by electorate',
#  'was julius evola well known',
#  'was jusuf kalla asked to run for vice president in 2014 or did he decide on his own',
#  'was kanjani eight popular',
#  'was ken kavanaugh large guy',
#  'was kudlow in government',
#  'was louis xviii of france liked in london',
#  'was mala i mousiki tou anemou successful',
#  'was mary surratt also sentenced to death',
#  'was mc hammers album lets get it started well received',
#  'was money returned to victims defrauded by scott rothstein and his firm',
#  'was music for jilted generation album successful',
#  'was new scheme part of islam',
#  'was nickell actor',
#  'was patsy clines second contract less limiting than her first',
#  'was person of interest by dj paul hit',
#  'was popes wedding starring gary oldman successful',
#  'was ps i love you start of sharon cuneta career',
#  'was queensrches mindcrime successful album',
#  'was reign in blood well received by critics',
#  'was reputation and repertoire album',
#  'was requiem for indifferent popular',
#  'was revival successful',
#  'was sad wings of destiny album successful',
#  'was salzburg responsible for daniel barenboims career',
#  'was scott w rothstein found guilty as result of these settlement cases',
#  'was shia labeouf luke turner and nastja säde rönkkö collaboration successful',
#  'was someone new brought in to replace kusch and grapow after they left helloween',
#  'was song all young dudes in any other movies besides in 1995 film clueless 2007 jason reitman film juno and 2008 film wackness',
#  'was song all young dudes successful',
#  'was stan kenton immediately successful',
#  'was stanford experiment ethical',
#  'was substance by new order another album',
#  'was supergirl related to super man',
#  'was that 1969 trip lee trevinos first time at masters',
#  'was that was week that was cancelled',
#  'was that was week that was in other countries besides canada',
#  'was that was week that was success',
#  'was there anybody else in tim kaines 2005 gubernatorial election race',
#  'was there anyone else of note involved in william regal from ruthless roundtables feud',
#  'was there anyone else paul ryan ran against in other 8 times he ran',
#  'was there anything else interesting in this section besides rebel sweethearts album and singles chart rankings',
#  'was there anything else you can share about pierre monteux',
#  'was there anything special about show with elizabeth taylor',
#  'was there final war between charles v and france',
#  'was there left and right in georg wilhelm friedrich hegels influence as represented by two opposing camps',
#  'was there storyline associated with william regals feud in ruthless roundtable',
#  'was there third mixtape from drake',
#  'was there third war during charles vs wars with france',
#  'was this end of pierre monteuxs career',
#  'was this volume three 19401942 collection quite popular',
#  'was tony parker dating another woman while married to eva longoria',
#  'was us version of that was week that was most successful',
#  'was van morrison van morrisons real name',
#  'was vladimir kozlovs attempt at being free agent successful',
#  'was walter winterbottom successful as national director',
#  'was weather report album release when new band formed',
#  'was wesley clark known for anything',
#  'were all same members of band we are scientists members of brain thrust mastery',
#  'were beatles broken up when real love was written by john lennon',
#  'were caravan of fur traders travelling with whitman able to help people out west',
#  'were caravan of fur traders travelling with whitman going west to be missionaries too',
#  'were p g wodehouses novels popular',
#  'were there any attempts to overthrow frederick as emperor',
#  'were there any flaws in hans christopher christiansens bethlehem water works',
#  'were there any other controversies regarding international version of that was week that was',
#  'were there any other countries involved with replicating that was week that was',
#  'were there any problems with immanuel kants theory',
#  'were there any singles from tape deck heart',
#  'were there any victories for billy gunn',
#  'were there philosophers robert owen based his models for socialism on',
#  'were there special rules that were part of new scheme',
#  'were wallflowers with any other labels during hiatus',
#  'were walter winterbottoms national coaching scheme with summer residential courses successful',
#  'what abebe bikila successful',
#  'what about environmental factors during bronze age collapse',
#  'what about health effects of being vegan versus being vegetarian',
#  'what about kemp members of spandau ballet',
#  'what accomplishment was nadia comaneci first gymnast to achieve',
#  'what actors were on that was week that was',
#  'what album did replacements release in 1981',
#  'what are advantages of realtime processing in realtime databases',
#  'what are alternative words and phrases for idiom out of blue',
#  'what are anemias possible causes',
#  'what are baby back pork ribs',
#  'what are banks that issue bank notes in scotland',
#  'what are beginnings of ancient hawaiian kapu system like',
#  'what are benefits of lasik',
#  'what are best ways to cook turkey',
#  'what are blockchains other uses in business',
#  'what are britpops roots and what influenced it',
#  'what are characteristics of surrealism movement',
#  'what are common types of depression',
#  'what are common variations of tagliatelle al ragu bolognese',
#  'what are dalis most iconic works',
#  'what are dangers of global warming',
#  'what are differences between baby back ribs and spareribs',
#  'what are differences between book and movies of neverending story',
#  'what are differences between intracellular and extracellular compartments',
#  'what are different kinds of chemical reactions',
#  'what are different types of chemical compounds',
#  'what are different types of lavender plants',
#  'what are different types of tachycardia',
#  'what are effects on vitamins and minerals on binge drinking',
#  'what are enumerated powers of congress',
#  'what are examples of important realtime databases',
#  'what are famous foods from emiliaromagna',
#  'what are functions of phospholipid bilayer',
#  'what are good sources of melatonin in food',
#  'what are good sources of vitamin b12',
#  'what are health benefits of lavender oil',
#  'what are implications of blockchain for society',
#  'what are important applications of realtime databases',
#  'what are important cloud options for realtime databases',
#  'what are important factors led to supertankers development',
#  'what are important functions of cell membrane',
#  'what are indigenous people national definitions used for',
#  'what are jesus christs two natures',
#  'what are main breeds of goat',
#  'what are main layers in oceanic crust',
#  'what are main types of cattle farming',
#  'what are main types of virtual machines',
#  'what are meshuggah',
#  'what are most common breeds of cattle for meat',
#  'what are most popular indian spices',
#  'what are most wellknown roles of anders holm',
#  'what are netflixs other competitors than blockbuster',
#  'what are orson scott cards pseudonyms',
#  'what are other famous song by migos',
#  'what are other good sources of calcium besides milk',
#  'what are popular musics characteristics',
#  'what are pros and cons of electric cars',
#  'what are pygmy goats used for',
#  'what are quartiles',
#  'what are recent changes for united states travel visa holders',
#  'what are red blood cells',
#  'what are replacements most known for',
#  'what are risks of lasik',
#  'what are safety features of tesla model 3',
#  'what are sam brownbacks views on healthcare',
#  'what are short and longterm effects of binge drinking on brain chemicals',
#  'what are side effects of melatonin',
#  'what are some examples of kapu in hawaiian society',
#  'what are some important aspects of ur group',
#  'what are some indigenous people national definitions',
#  'what are some lyrical themes in roots reggae',
#  'what are some negatives or failures of frederick iis reign',
#  'what are some of possible causes of bronze age collapse',
#  'what are some other important things to know about indigenous peoples of americas music and art besides characteristics and how well known music and art is',
#  'what are some other versions of i will always love you',
#  'what are some specific recommendations of balanced diet for women',
#  'what are supertankers',
#  'what are symptoms of anemia',
#  'what are tofus origins',
#  'what are two main fluid compartments in human body for water',
#  'what are types of blockchain networks',
#  'what are types of lipids',
#  'what are typical pasta dishes from emiliaromagna',
#  'what are ways to cook pork ribs',
#  'what are wingy manones songs besides tar paper stomp',
#  'what arethe applications and uses of corn syrup',
#  'what baseball team did sam thompson play for',
#  'what breed of goats is good for meat',
#  'what came after bronze age collapse',
#  'what came after hellenistic period',
#  'what can be used instead of mdot',
#  'what can you tell me about peter hitchens on sir alan duncan',
#  'what career path did timur take',
#  'what causes depression',
#  'what causes irregular heartbeat',
#  'what children did prince philip duke of edinburgh have',
#  'what city were backstreet boys in when they were first signed and discovered',
#  'what coaches participated in walter winterbottoms new coaching scheme',
#  'what college did tom cousineau go to',
#  'what collegiate conference of sports did robert maynard hutchins pull university of chicago out of',
#  'what comes after business name when lettering mail to business',
#  'what comprises balanced diet',
#  'what connection does mwai kibaki have with constitutional referendum',
#  'what convention was covered in article on william h seward',
#  'what countries do i need visa for with american passport',
#  'what cuisines use spices heavily',
#  'what defines chemical element',
#  'what defines feature film',
#  'what degree did robert maynard hutchins make known for two year studies',
#  'what did 2005 general election pertain to',
#  'what did 5th commandment state in animal farm',
#  'what did abebe bikila do in olympics',
#  'what did alexander graham bell do at school of vocal physiology and mechanics of speech',
#  'what did alison moyet do in 1990',
#  'what did band beach boys use theremin for',
#  'what did beatles do',
#  'what did bill robinson and shirley temple perform in',
#  'what did billy graham do after his presidency of bible college',
#  'what did billy graham do for church from 1943 to 1944',
#  'what did charles kennedy do after he resigned',
#  'what did charles kennedy say at his january 7 2006 press conference',
#  'what did chinua achebe do in his fellowship travels',
#  'what did clive davis say at whitney houstons funeral',
#  'what did columbus delano do as president of national association of wool growers',
#  'what did columbus delano do later in life after being fired from federal government',
#  'what did eddie cantor do as career',
#  'what did eddie collins rejoin to athletics as',
#  'what did entry into world war 1 mean for united states',
#  'what did frank moss do',
#  'what did frank swift do after retiring from football in 1949',
#  'what did gackt do in 2007',
#  'what did gary oldman do in 2000 of note',
#  'what did gavin newsom do as mayor',
#  'what did george bernard shaw do when he finished school',
#  'what did historians say about georg wilhelm friedrich hegel',
#  'what did j r jayewardene do in his early life',
#  'what did jackie coogan study',
#  'what did james traficants parents do',
#  'what did jascha heifetz do after retirement',
#  'what did jean lapierre do as minister of transport',
#  'what did jeb bush do next after being branch manager of new venezuela branch of texas commerce bank',
#  'what did judy chicago arlene raven and sheila levrant de brettevillear do together',
#  'what did jusuf kalla do after elections',
#  'what did larry kudlow do while he was working in government',
#  'what did lew wallace do for us military',
#  'what did lew wallace write in paper free soil banner',
#  'what did lou groza do later in life',
#  'what did lou grozas wife have',
#  'what did louis xviii of france do in england',
#  'what did louis xviii of france need asylum from',
#  'what did lucy stone do in executive comittee of american equal rights association',
#  'what did mary surratt die of',
#  'what did mc hammer do in entertainment other than music',
#  'what did musician ray price do in 1960s',
#  'what did patsy cline record for four star',
#  'what did privatization have to do with oligarchs',
#  'what did pugin do in australia',
#  'what did rahul bose begin his career doing',
#  'what did ray price work together on with cherokee cowboys and willie nelson',
#  'what did rebel wilson do after westie monologues',
#  'what did rebel wilson do first early in her career',
#  'what did rebel wilson do in new york',
#  'what did reviewers say about movie once',
#  'what did richard jones do next',
#  'what did richard nixon do after gerald fords pardon',
#  'what did sam thompson do next after retiring and investing in real estate',
#  'what did scoreboard read when nadia comăneci scored her first perfect 100',
#  'what did showbread look like',
#  'what did small faces do during their hiatus',
#  'what did stan kenton do after leaving in 1937',
#  'what did stan kenton start out doing in his career',
#  'what did stanford experiment show',
#  'what did stephen colbert study',
#  'what did susan egan do on broadway',
#  'what did tariq black thought trotter and ahmir questlove thompson do during high school after meeting',
#  'what did they do at th lyceum',
#  'what did vladimir kozlov do next',
#  'what did wallflowers do in 2004',
#  'what did we are scientists do for drummer then after their drummer michael tapper left',
#  'what did wilhelm furtwanger teach daniel barenboim',
#  'what difference between physician assistant and nurse practitioner',
#  'what discussions did rosalynn carter have with latin americas leaders',
#  'what do blue whales eat',
#  'what do orca whales eat',
#  'what do rock performers do in oneman band performance',
#  'what do spanish people do on christmas day',
#  'what do spanish people eat for christmas dinner',
#  'what do spanish people eat on christmas eve',
#  'what do they have to do with nickell',
#  'what does dot over mass flow rate symbol mean',
#  'what does dra stand for',
#  'what does elton john aids foundation do',
#  'what does it cost to become physicians assistant',
#  'what does john rawl see as decent person',
#  'what does liberal mean in context of john rawls law of peoples',
#  'what does suppressio veri mean',
#  'what does title monsignor mean in catholic church',
#  'what does vladimir kozlov article mean by face character',
#  'what else besides inviestigating funding did cliff stearns do regarding abortion',
#  'what else can you tell me about gary ablett jr that has followed in gary ablett sr footsteps to play for geelong',
#  'what else can you tell me about time pierre monteux was conductor',
#  'what else can you tell me about walter winterbottoms time as fa director of coaching besides appointment successes and inspiring new generation of managers',
#  'what else can you tell me of importance to rosalynn carter article',
#  'what else did ahmadis do under new scheme',
#  'what else did alison moyet record in 1990s besides hoodoo',
#  'what else did beatles do to affectchange music scene besides development of counterculture',
#  'what else did columbus delano do in his career prior to politics',
#  'what else did frederick ii achieve',
#  'what else did gerald ford do during time of pardon of nixon besides pardon of nixon',
#  'what else did lee trevino say about masters at this time',
#  'what else did rosalynn carter say',
#  'what else did tris speaker accomplish besides his 792 career doubles represent mlb career record',
#  'what else did ukrainians do in their early history besides establishment of zaporizhian',
#  'what else did you find interesting after journey set on new path with more mainstream sound to make their highest chart success to date',
#  'what else does joe lieberman support',
#  'what else happened following three stooges collection successful release',
#  'what else happened in juan sebastián veróns second season',
#  'what else happened to mohammed zahir shah in 1973 besides exile',
#  'what else has sam brownback done in government that shows his views on healthcare besides fda administration amendments act of 2007 and insurance portability',
#  'what else is important about olivia dunhams fauxlivia besides shared major similarities',
#  'what else is interesting about 20062009 of drakes career',
#  'what else is interesting about shia labeoufs connection to performance art besides iamsorry allmymovies touchmysoul takemeanywhere and hewillnotdivideus',
#  'what else is issue on broken gimmick over',
#  'what else is showbread called',
#  'what else major did dominick argento go through',
#  'what else was bad about juan sebastián veróns time at old trafford',
#  'what else was notable about juan sebastián veróns second season other than his injury fans agreeing his signing was expensive flop and excelling in champions league',
#  'what empires survived bronze age collapse',
#  'what enhanced jimmy pages recording of album led zeppelin',
#  'what era did british invasion in music happen',
#  'what era is great gatsby set in',
#  'what events proceeded white terror in taiwan',
#  'what fact stands out most to you about film tiny furniture besides awards and dunhams family being cast',
#  'what fields use mdot notation',
#  'what film was eunice elizabeth sargaison in',
#  'what films did katrina kaif appear with akshay kumar',
#  'what films is catherine mccormack known for',
#  'what foods contain high levels of iron',
#  'what foods is lavender good for cooking with',
#  'what forms of art did iberians use',
#  ...]

# %% [markdown]
# 0.3173819079962952

# %% [markdown]
# Compute rc loss for paraphrased rewrites

# %%
qrecc = qrecc.filter(lambda x: isinstance(x['passage'], str))
# Out:
#   0%|          | 0/25 [00:00<?, ?ba/s]
#   0%|          | 0/7 [00:00<?, ?ba/s]

# %%
para_tokenizer = AutoTokenizer.from_pretrained("Vamsi/T5_Paraphrase_Paws")  
para_model = AutoModelForSeq2SeqLM.from_pretrained("Vamsi/T5_Paraphrase_Paws")

# %%
device = torch.device('cuda')
t5_model.to(device)
para_model.to(device)

t5_model.load_state_dict(torch.load('/home/ujan/Documents/conv-qa/models/finetuned_weights/new_rc_gen5.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Augment dataset

# %%
def update(example):
    
    passage = t5_tokenizer(example['rewrite'], example['passage'], padding=True, truncation='only_second',
                           max_length=max_length, add_special_tokens=True, return_tensors="pt")
    answer = t5_tokenizer(example['answer'], padding=True, truncation='only_second',
                          max_length=max_length, add_special_tokens=True, return_tensors="pt")
    
    psg_input = passage.input_ids.to(device)
    psg_attention = passage.attention_mask.to(device)
    ans_input = answer.input_ids
    ans_input[ans_input == t5_tokenizer.pad_token_id] = -100
    ans_input = ans_input.to(device)
    
    org_loss = t5_model(input_ids=psg_input, attention_mask=psg_attention, labels=ans_input).loss.item()
    
    para_loss = {}
    losses = []
    
    sentence = example['rewrite']

    text =  "paraphrase: " + sentence + " </s>"

    encoding = para_tokenizer.encode_plus(text, padding=True, return_tensors="pt")
    input_ids = encoding["input_ids"].to(device)
    attention_masks = encoding["attention_mask"].to(device)
    
    outputs = para_model.generate(
    input_ids=input_ids, attention_mask=attention_masks,
    max_length=256,
    do_sample=True,
    top_k=120, # 120
    top_p=0.95,
    early_stopping=True,
    num_return_sequences=10)

    for output in outputs:
        line = para_tokenizer.decode(output, skip_special_tokens=True, clean_up_tokenization_spaces=True)
        passage = t5_tokenizer(line, example['passage'], padding=True, truncation='only_second',
                           max_length=max_length, add_special_tokens=True, return_tensors="pt")
        
        psg_input = passage.input_ids.to(device)
        psg_attention = passage.attention_mask.to(device)
    
        loss = t5_model(input_ids=psg_input, attention_mask=psg_attention, labels=ans_input).loss.item()
        para_loss[line] = loss
        losses.append(loss)
        
    if any(p < org_loss for p in losses):
        example['rewrite'] = min(para_loss, key=para_loss.get)
    
    return example

# %%
qrecc['train'] = qrecc['train'].map(update)
# Out:
#   0%|          | 0/24037 [00:00<?, ?ex/s]

# %%
qrecc.save_to_disk("/home/ujan/Desktop/qrecc")
# Out:
# Flattening the indices:   0%|          | 0/7 [00:00<?, ?ba/s]

# %%
qrecc = load_from_disk("/home/ujan/Desktop/qrecc")

# %%
def tokenize_dataset(batch):

  passages = t5_tokenizer(batch['rewrite'], batch['passage'], padding='max_length', truncation='only_second', max_length=max_length, add_special_tokens=True)
  answers = t5_tokenizer(batch['answer'], padding='max_length', truncation=True, max_length=max_length, add_special_tokens=True)

  batch['psg_input_ids'] = passages.input_ids
  batch['ans_input_ids']  = answers.input_ids
  batch['psg_attention_mask'] = passages.attention_mask

  return batch


# handle examples with no answers
def no_ans(x):
  if isinstance(x['answer'], str): return x
  x['answer'] = 'no_ans'
  return x


# removing examples with no context
qrecc = qrecc.filter(lambda x: isinstance(x['passage'], str))

# removing examples with passage length > 384
#qrecc = qrecc.filter(lambda x: len(e_tokenizer(x['passage']).input_ids) <= max_length)

# no answers
qrecc = qrecc.map(no_ans)

# tokenizing
dataset = qrecc.map(
    tokenize_dataset, 
    batch_size = batch_size,
    batched=True,
    remove_columns=['passage', 'answer', 'rewrite']
)


dataset.set_format(
    type='torch', columns=['psg_input_ids', 'ans_input_ids', 'psg_attention_mask'],)
# Out:
#   0%|          | 0/25 [00:00<?, ?ba/s]
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/24037 [00:00<?, ?ex/s]
#   0%|          | 0/6478 [00:00<?, ?ex/s]
#   0%|          | 0/1503 [00:00<?, ?ba/s]
#   0%|          | 0/405 [00:00<?, ?ba/s]

# %%
train_loader = torch.utils.data.DataLoader(dataset['train'], batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(dataset['test'], batch_size=batch_size)

# %% [markdown]
# train para e2e with rc

# %%
num_epochs = 6

device = torch.device('cuda')
t5_tokenizer = T5Tokenizer.from_pretrained(pretrained_model)

t5_model = T5ForConditionalGeneration.from_pretrained(pretrained_model)
t5_model.to(device)

#t5_model.load_state_dict(torch.load('/home/ujan/Documents/conv-qa/models/finetuned_weights/rc_gen5.pth'))

t5_model.train()


optim = optimizer = Adafactor(
    t5_model.parameters(),
    lr=1e-5,
    eps=(1e-30, 1e-3),
    clip_threshold=1.0,
    decay_rate=-0.8,
    beta1=None,
    weight_decay=0.0,
    relative_step=False,
    scale_parameter=False,
    warmup_init=False
)

for epoch in range(num_epochs):
  
  epoch_loss = 0

  for batch in train_loader:

    # rewrite+passge inputs for encoder
    psg_input = batch['psg_input_ids'].to(device)
    psg_attention = batch['psg_attention_mask'].to(device)

    # answer inputs for rc
    ans_input = batch['ans_input_ids'] 
    ans_input[ans_input == t5_tokenizer.pad_token_id] = -100
    ans_input = ans_input.to(device)

    # rc loss
    loss = t5_model(input_ids=psg_input, attention_mask=psg_attention, labels=ans_input).loss

    epoch_loss += loss.item()

    loss.backward()
    optim.step()
    optim.zero_grad()
    

  print('Train loss after epoch {} : {}'.format(epoch+1, epoch_loss / len(train_loader)))
  t5_model.eval()
  print('Valid loss after epoch {} : {}'.format(epoch+1, valid_loss()))
  
  print('\n')
  t5_model.train()
  torch.save(t5_model.state_dict(), '/home/ujan/Documents/rc_gen'+str(epoch+1)+'.pth')
# Out:
# Train loss after epoch 1 : 0.7852077122854536
# Valid loss after epoch 1 : 0.6146532967870618
#
#
# Train loss after epoch 2 : 0.6046948571722268
# Valid loss after epoch 2 : 0.581035594255836
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5486/1742291225.py in <module>
#      43     loss = t5_model(input_ids=psg_input, attention_mask=psg_attention, labels=ans_input).loss
#      44
# ---> 45     epoch_loss += loss.item()
#      46
#      47     loss.backward()
#
# KeyboardInterrupt:

# %% [markdown]
# Train qr with new dataset
